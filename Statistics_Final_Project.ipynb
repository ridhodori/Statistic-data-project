# %% [markdown]
# <a href="https://colab.research.google.com/github/ridhodori/Statistic-data-project/blob/main/Statistics_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Group 7
# - Ridho Nobelino S
# - Dharaka Pranamya Mahadhika Damar
# - Dzaki Mahadika Gunarto
# - Aine Rudcoll Rama Kemas

# %%
 data<-read.csv("BankChurners.csv")
head(data)


hist(data$Customer_Age, border= "red", col="blue")
hist(data$Months_on_book)
pie(table(data$Income_Category))
pie(table(data$Education_Level))
barplot(table(data$Income_Category, data$Customer_Age))
plot(data$Customer_Age,data$CLIENTNUM)
plot(data$Dependent_count	, type ="l")
datanew <- data[1:11]
head(datanew)
as.matrix(datanew)
t(datanew)
dotchart(data$Months_on_book)
Max_Age <- max(data$Customer_Age)
print(Max_Age)
Min_Age <- min(data$Customer_Age)
print(Min_Age)
Average_Age <- mean(data$Customer_Age)
print(Average_Age)

Mariage <- subset(data, Gender == "M" & Marital_Status== "Married")
print('Head Mariage Table')
print(head(Mariage))
print('Tail Mariage Table')
print(tail(Mariage))

Education <- subset(data, Customer_Age > 50 & Marital_Status == "Married" & Education_Level == "High School")
print('Head Education Table')
print(head(Education))
# Out:
#   CLIENTNUM Attrition_Flag    Customer_Age Gender Dependent_count
# 1 768805383 Existing Customer 45           M      3
# 2 818770008 Existing Customer 49           F      5
# 3 713982108 Existing Customer 51           M      3
# 4 769911858 Existing Customer 40           F      4
# 5 709106358 Existing Customer 40           M      3
# 6 713061558 Existing Customer 44           M      2
#   Education_Level Marital_Status Income_Category Card_Category Months_on_book ⋯
# 1 High School     Married        $60K - $80K     Blue          39             ⋯
# 2 Graduate        Single         Less than $40K  Blue          44             ⋯
# 3 Graduate        Married        $80K - $120K    Blue          36             ⋯
# 4 High School     Unknown        Less than $40K  Blue          34             ⋯
# 5 Uneducated      Married        $60K - $80K     Blue          21             ⋯
# 6 Graduate        Married        $40K - $60K     Blue          36             ⋯
# ...

# %%
data <- read.csv("BankChurners.csv")

pie(table(data$Attrition_Flag))
pie(table(data$Gender))
pie(table(data$Education_Level))
pie(table(data$Marital_Status))
pie(table(data$Income_Category))
pie(table(data$Card_Category))

Education1 <- subset(data, Customer_Age > 50 & Marital_Status == "Married" & Education_Level == "High School")
pie(table(Education1$Income_Category))

Mariage1 <- subset(data, Gender == "M" & Marital_Status== "Married")
pie(table(Mariage1$Income_Category))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#Customer_Age
Max_Age <- max(data$Customer_Age)
Max_Age1 <- "Max Age : "
print(paste(Max_Age1, Max_Age))
Min_Age <- min(data$Customer_Age)
Min_Age1 <- "Min Age : "
print(paste(Min_Age1, Min_Age))
Average_Age <- mean(data$Customer_Age)
Average_Age1 <- "Average Age : "
print(paste(Average_Age1, Average_Age))
# Out:
# [1] "Max Age :  73"
# [1] "Min Age :  26"
# [1] "Average Age :  46.3259603041375"

# %%
#Months_on_book
Max_Months_on_book <- max(data$Months_on_book)
Max_Months_on_book1 <- "Max Months on book : "
print(paste(Max_Months_on_book1, Max_Months_on_book))
Min_Months_on_book <- min(data$Months_on_book)
Min_Months_on_book1 <- "Min Months on book : "
print(paste(Min_Months_on_book1, Min_Months_on_book))
Average_Months_on_book <- mean(data$Months_on_book)
Average_Months_on_book1 <- "Average Months on book : "
print(paste(Average_Months_on_book1, Average_Months_on_book))
# Out:
# [1] "Max Months on book :  56"
# [1] "Min Months on book :  13"
# [1] "Average Months on book :  35.9284092031204"

# %%
#Credit_Limit
Max_Credit_Limit <- max(data$Credit_Limit)
Max_Credit_Limit1 <- "Max Credit_Limit : "
print(paste(Max_Credit_Limit1, Max_Credit_Limit))
Min_Credit_Limit <- min(data$Credit_Limit)
Min_Credit_Limit1 <- "Min Credit_Limit : "
print(paste(Min_Credit_Limit1, Min_Credit_Limit))
Average_Credit_Limit <- mean(data$Credit_Limit)
Average_Credit_Limit1 <- "Average Credit_Limit : "
print(paste(Average_Credit_Limit1, Average_Credit_Limit))
# Out:
# [1] "Max Credit_Limit :  34516"
# [1] "Min Credit_Limit :  1438.3"
# [1] "Average Credit_Limit :  8631.95369803496"

# %%
sumexists <- sum(data$Attrition_Flag == "Existing Customer")
sumexists1 <- "Sum of Existing Customer :"
print(paste(sumexists1, sumexists))
sumattrited <- sum(data$Attrition_Flag == "Attrited Customer")
sumattrited1 <- "Sum of Attrited Customer :"
print(paste(sumattrited1, sumattrited))

x <- c(8500, 1627)
labels <- c("Existing Customer", "Attrited Customer")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Attrition Flag (In %)", col = rainbow(length(x)))
legend("topright", c("Existing Customer", "Attrited Customer"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Existing Customer : 8500"
# [1] "Sum of Attrited Customer : 1627"
# Plot with title “Attrition Flag (In %)”

# %%
summale <- sum(data$Gender == "M")
summale1 <- "Sum of Male :"
print(paste(summale1, summale))
sumfemale <- sum(data$Gender == "F")
sumfemale1 <- "Sum of Female :"
print(paste(sumfemale1, sumfemale))

x <- c(4769, 5358)
labels <- c("Male", "Female")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Gender (In %)", col = rainbow(length(x)))
legend("topright", c("Male", "Female"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Male : 4769"
# [1] "Sum of Female : 5358"
# Plot with title “Gender (In %)”

# %%
sumGraduate <- sum(data$Education_Level == "Graduate")
sumGraduate1 <- "Sum of Graduate :"
print(paste(sumGraduate1, sumGraduate))
sumDoctorate <- sum(data$Education_Level == "Doctorate")
sumDoctorate1 <- "Sum of Doctorate :"
print(paste(sumDoctorate1, sumDoctorate))
sumCollege <- sum(data$Education_Level == "College")
sumCollege1 <- "Sum of College :"
print(paste(sumCollege1, sumCollege))
sumUnknown <- sum(data$Education_Level == "Unknown")
sumUnknown1 <- "Sum of Unknown :"
print(paste(sumUnknown1, sumUnknown))
sumUneducated <- sum(data$Education_Level == "Uneducated")
sumUneducated1 <- "Sum of Uneducated :"
print(paste(sumUneducated1, sumUneducated))
sumPostGraduate <- sum(data$Education_Level == "Post-Graduate")
sumPostGraduate1 <- "Sum of Post-Graduate :"
print(paste(sumPostGraduate1, sumPostGraduate))
sumHS <- sum(data$Education_Level == "High School")
sumHS1 <- "Sum of High School :"
print(paste(sumHS1, sumHS))

x <- c(3128, 451, 1013, 1519, 1487, 516, 2013)
labels <- c("Graduate", "Doctorate", "College", "Unknown", "Uneducated", "Post-Graduate", "High School")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Education Level (In %)", col = rainbow(length(x)))
legend("topright", c("Graduate", "Doctorate", "College", "Unknown", "Uneducated", "Post-Graduate", "High School"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Graduate : 3128"
# [1] "Sum of Doctorate : 451"
# [1] "Sum of College : 1013"
# [1] "Sum of Unknown : 1519"
# [1] "Sum of Uneducated : 1487"
# [1] "Sum of Post-Graduate : 516"
# [1] "Sum of High School : 2013"
# Plot with title “Education Level (In %)”

# %%
sumMarried <- sum(data$Marital_Status == "Married")
sumMarried1 <- ("Sum of Married Data :")
print(paste(sumMarried1, sumMarried))
sumDivorced <- sum(data$Marital_Status == "Divorced")
sumDivorced1 <- ("Sum of Divorced Data :")
print(paste(sumDivorced1, sumDivorced))
sumUnknown <- sum(data$Marital_Status == "Unknown")
sumUnknown1 <- ("Sum of Unknown Data :")
print(paste(sumUnknown1, sumUnknown))
sumSingle <- sum(data$Marital_Status == "Single")
sumSingle1 <- ("Sum of Single Data :")
print(paste(sumSingle1, sumSingle))

x <- c(4687, 748, 749, 3943)
labels <- c("Married", "Divorced", "Unknown", "Single")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Marital Status (In %)", col = rainbow(length(x)))
legend("topright", c("Married", "Divorced", "Unknown", "Single"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Married Data : 4687"
# [1] "Sum of Divorced Data : 748"
# [1] "Sum of Unknown Data : 749"
# [1] "Sum of Single Data : 3943"
# Plot with title “Marital Status (In %)”

# %%
sum40 <- sum(data$Income_Category == "Less than $40K")
sum401 <- ("Sum of Data Income Less than $40K :")
print(paste(sum401, sum40))
sum4060 <- sum(data$Income_Category == "$40K - $60K")
sum40601 <- ("Sum of Data Income $40K - $60K :")
print(paste(sum40601, sum4060))
sum6080 <- sum(data$Income_Category == "$60K - $80K")
sum60801 <- ("Sum of Data Income $60K - $80K :")
print(paste(sum60801, sum6080))
sum80120 <- sum(data$Income_Category == "$80K - $120K")
sum801201 <- ("Sum of Data Income $80K - $120K :")
print(paste(sum801201, sum80120))
sum120 <- sum(data$Income_Category == "$120K +")
sum1201 <- ("Sum of Data Income $120K + :")
print(paste(sum1201, sum120))
sumUnknown <- sum(data$Income_Category == "Unknown")
sumUnknown1 <- ("Sum of Data Income Unknown :")
print(paste(sumUnknown1, sumUnknown))

x <- c(3561, 1790, 1402, 1535, 727, 1112)
labels <- c("Less than $40K", "$40K - $60K", "$60K - $80K", "$80K - $120K", "$120K +", "Unknown")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Income Category (In %)", col = rainbow(length(x)))
legend("topright", c("Less than $40K", "$40K - $60K", "$60K - $80K", "$80K - $120K", "$120K +", "Unknown"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Data Income Less than $40K : 3561"
# [1] "Sum of Data Income $40K - $60K : 1790"
# [1] "Sum of Data Income $60K - $80K : 1402"
# [1] "Sum of Data Income $80K - $120K : 1535"
# [1] "Sum of Data Income $120K + : 727"
# [1] "Sum of Data Income Unknown : 1112"
# Plot with title “Income Category (In %)”

# %%
sumBlue <- sum(data$Card_Category == "Blue")
sumBlue1 <- ("Sum of Blue Card Category Data :")
print(paste(sumBlue1, sumBlue))
sumSilver <- sum(data$Card_Category == "Silver")
sumSilver1 <- ("Sum of Silver Card Category Data :")
print(paste(sumSilver1, sumSilver))
sumGold <- sum(data$Card_Category == "Gold")
sumGold1 <- ("Sum of Gold Card Category Data :")
print(paste(sumGold1, sumGold))
sumPlatinum <- sum(data$Card_Category == "Platinum")
sumPlatinum1 <- ("Sum of Platinum Card Category Data :")
print(paste(sumPlatinum1, sumPlatinum))

x <- c(9436, 555, 116, 20)
labels <- c("Blue", "Silver", "Gold", "Platinum")

piepercent<- round(100*x/sum(x), 1)

pie(x, labels = piepercent, main = "Card Category (In %)", col = rainbow(length(x)))
legend("topright", c("Blue", "Silver", "Gold", "Platinum"), cex = 0.8, fill = rainbow(length(x)))
# Out:
# [1] "Sum of Blue Card Category Data : 9436"
# [1] "Sum of Silver Card Category Data : 555"
# [1] "Sum of Gold Card Category Data : 116"
# [1] "Sum of Platinum Card Category Data : 20"
# Plot with title “Card Category (In %)”

# %%
hist(data$Customer_Age)
hist(data$Months_on_book)
hist(data$Dependent_count)
hist(data$Credit_Limit)
hist(data$Total_Relationship_Count)
hist(data$Months_Inactive_12_mon)
hist(data$Contacts_Count_12_mon)
hist(data$Credit_Limit)
hist(data$Total_Revolving_Bal)
hist(data$Avg_Open_To_Buy)
hist(data$Total_Amt_Chng_Q4_Q1)
hist(data$Total_Trans_Amt)
hist(data$Total_Trans_Ct)
hist(data$Total_Ct_Chng_Q4_Q1)
hist(data$Avg_Utilization_Ratio)
hist(data$Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)
hist(data$Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2)
# Out:
# Plot with title “Histogram of data$Customer_Age”
# Plot with title “Histogram of data$Months_on_book”
# Plot with title “Histogram of data$Dependent_count”
# Plot with title “Histogram of data$Credit_Limit”
# Plot with title “Histogram of data$Total_Relationship_Count”
# Plot with title “Histogram of data$Months_Inactive_12_mon”
# Plot with title “Histogram of data$Contacts_Count_12_mon”
# Plot with title “Histogram of data$Credit_Limit”
# Plot with title “Histogram of data$Total_Revolving_Bal”
# Plot with title “Histogram of data$Avg_Open_To_Buy”
# Plot with title “Histogram of data$Total_Amt_Chng_Q4_Q1”
# Plot with title “Histogram of data$Total_Trans_Amt”
# Plot with title “Histogram of data$Total_Trans_Ct”
# Plot with title “Histogram of data$Total_Ct_Chng_Q4_Q1”
# Plot with title “Histogram of data$Avg_Utilization_Ratio”
# ...

# %%
plot(data$Customer_Age)
# Out:
# plot without title

# %%
barplot(table(data$Income_Category, data$Customer_Age))
# Out:
# plot without title

# %%
barplot(table(data$Customer_Age))
barplot(table(data$Months_on_book))
# Out:
# plot without title
# plot without title

# %%
datanew1 <- data[, 1:11]
nba_matrix <- data.matrix(datanew1)
nba_heatmap <- heatmap(nba_matrix, Rowv=NA, Colv=NA, col = heat.colors(256), scale="column", margins=c(5,10))
# Out:
# plot without title

# %%
heatmap(table(data$Education_Level, data$Income_Category), margins = c(10, 8))
# Out:
# plot without title

# %%
cor.test(data$Customer_Age,data$Dependent_count)
cor.test(data$Months_on_book, data$Dependent_count)
# Out:
# 	Pearson's product-moment correlation
#
# data:  data$Customer_Age and data$Dependent_count
# t = -12.395, df = 10125, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.1413939 -0.1030223
# sample estimates:
#        cor
# -0.1222538
# 	Pearson's product-moment correlation
#
# data:  data$Months_on_book and data$Dependent_count
# t = -10.426, df = 10125, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.12229358 -0.08375362
# sample estimates:
#        cor
# -0.1030623

# %%
datacor<-table(data$Months_on_book,data$Dependent_count)
chisq.test(datacor,correct = FALSE)$expected
dataagain<-table(data$Customer_Age,data$Months_on_book)
chisq.test(dataagain,correct = FALSE)
# Out:
# Warning message in chisq.test(datacor, correct = FALSE):
# “Chi-squared approximation may be incorrect”
#
#      0          1          2          3          4          5
#   13   6.248642  12.704651  18.351930  18.884171  10.879826   2.9307791
#   14   1.428261   2.903920   4.194727   4.316382   2.486817   0.6698924
#   15   3.035055   6.170830   8.913795   9.172312   5.284487   1.4235213
#   16   2.588723   5.263355   7.602943   7.823442   4.507357   1.2141799
#   17   3.481386   7.078306  10.224647  10.521181   6.061617   1.6328626
#   18   5.177446  10.526711  15.205885  15.646885   9.014713   2.4283598
#   19   5.623778  11.434186  16.516737  16.995754   9.791844   2.6377012
#   20   6.605708  13.430631  19.400612  19.963267  11.501531   3.0982522
#   21   7.409104  15.064086  21.760146  22.391231  12.900365   3.4750667
#   22   9.372963  19.056976  27.527896  28.326257  16.319739   4.3961687
#   23  10.354893  21.053422  30.411771  31.293769  18.029426   4.8567197
# ...
